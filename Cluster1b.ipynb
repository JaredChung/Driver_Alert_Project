# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %matplotlib inline

# %%
data = pd.read_csv("DAM_Dataset_full.txt")
data2= pd.read_csv("DAM Data Set Session 1 (2).csv")

# %%
data.head()
# Out:
#    ID  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0   1                 1                              0.766127   45
# 1   2                 0                              0.957151   40
# 2   3                 0                              0.658180   38
# 3   4                 0                              0.233810   30
# 4   5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982           9120
# 1                                     0   0.121876           2600
# 2                                     1   0.085113           3042
# 3                                     0   0.036050           3300
# 4                                     1   0.024926          63588
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                               13                        0
# ...

# %%
data2
# Out:
#                            Variable Name  \
# 0                       SeriousDlqin2yrs
# 1   RevolvingUtilizationOfUnsecuredLines
# 2                                    age
# 3   NumberOfTime30-59DaysPastDueNotWorse
# 4                              DebtRatio
# 5                          MonthlyIncome
# 6        NumberOfOpenCreditLinesAndLoans
# 7                NumberOfTimes90DaysLate
# 8           NumberRealEstateLoansOrLines
# 9   NumberOfTime60-89DaysPastDueNotWorse
# 10                    NumberOfDependents
#
#                                           Description        Type
# 0   Person experienced 90 days past due delinquenc...         Y/N
# 1   Total balance on credit cards and personal lin...  percentage
# 2                            Age of borrower in years     integer
# 3   Number of times borrower has been 30-59 days p...     integer
# 4   Monthly debt payments, alimony,living costs di...  percentage
# 5                                      Monthly income        real
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5003 entries, 0 to 5002
# Data columns (total 12 columns):
# ID                                      5003 non-null int64
# SeriousDlqin2yrs                        5003 non-null int64
# RevolvingUtilizationOfUnsecuredLines    5003 non-null float64
# age                                     5003 non-null int64
# NumberOfTime30-59DaysPastDueNotWorse    5003 non-null int64
# DebtRatio                               5003 non-null float64
# MonthlyIncome                           4033 non-null float64
# NumberOfOpenCreditLinesAndLoans         5003 non-null int64
# NumberOfTimes90DaysLate                 5002 non-null float64
# NumberRealEstateLoansOrLines            5002 non-null float64
# NumberOfTime60-89DaysPastDueNotWorse    5002 non-null float64
# NumberOfDependents                      4860 non-null float64
# dtypes: float64(7), int64(5)
# memory usage: 508.1 KB

# %%
data.describe()
# Out:
#                 ID  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  5003.000000       5003.000000                           5003.000000
# mean   2502.000000          0.060963                              3.841728
# std    1444.386029          0.239287                            117.391642
# min       1.000000          0.000000                              0.000000
# 25%    1251.500000          0.000000                              0.030086
# 50%    2502.000000          0.000000                              0.163512
# 75%    3752.500000          0.000000                              0.556367
# max    5003.000000          1.000000                           6324.000000
#
#                age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  5003.000000                           5003.000000    5003.000000
# mean     52.126724                              0.355587     367.885289
# std      14.905162                              3.177679    2593.168720
# ...

# %%
data.isnull().sum()
# Out:
# ID                                        0
# SeriousDlqin2yrs                          0
# RevolvingUtilizationOfUnsecuredLines      0
# age                                       0
# NumberOfTime30-59DaysPastDueNotWorse      0
# DebtRatio                                 0
# MonthlyIncome                           970
# NumberOfOpenCreditLinesAndLoans           0
# NumberOfTimes90DaysLate                   1
# NumberRealEstateLoansOrLines              1
# NumberOfTime60-89DaysPastDueNotWorse      1
# NumberOfDependents                      143
# dtype: int64

# %%
data.age.sort_values(ascending=False).head()
# Out:
# 2922    99
# 436     97
# 2864    96
# 4627    95
# 4043    94
# Name: age, dtype: int64

# %%
data.groupby('SeriousDlqin2yrs').size()
# Out:
# SeriousDlqin2yrs
# 0    4698
# 1     305
# dtype: int64

# %%
float(305) / (float(4698) + float(305))
# Out:
# 0.0609634219468319

# %%
float(4699) / (float(4698) + float(305))
# Out:
# 0.9392364581251249

# %%
for n in data.columns:
    print '--------------------------'
    print data.groupby(n).size().sort_values(ascending=False).head()
# Out:
# --------------------------
# ID
# 5003    1
# 1671    1
# 1664    1
# 1665    1
# 1666    1
# dtype: int64
# --------------------------
# SeriousDlqin2yrs
# 0    4698
# 1     305
# dtype: int64
# --------------------------
# RevolvingUtilizationOfUnsecuredLines
# 0.000000    366
# 1.000000    353
# 0.086605      2
# 0.223678      2
# 0.012399      2
# dtype: int64
# --------------------------
# age
# 63    136
# 55    136
# 49    133
# 46    131
# 57    129
# dtype: int64
# --------------------------
# NumberOfTime30-59DaysPastDueNotWorse
# 0    4195
# 1     537
# 2     142
# 3      79
# 4      22
# dtype: int64
# --------------------------
# DebtRatio
# 0.0     131
# 2.0       9
# 1.0       8
# 10.0      7
# 13.0      7
# dtype: int64
# --------------------------
# MonthlyIncome
# 5000.0    86
# 4000.0    82
# 6000.0    63
# 3500.0    61
# 3000.0    59
# dtype: int64
# --------------------------
# NumberOfOpenCreditLinesAndLoans
# 6    475
# 5    456
# 8    414
# 7    406
# ...

# %%
sns.pairplot(data.dropna(axis=0).drop('ID',axis=1).iloc[:,0:4], hue='SeriousDlqin2yrs',size=3)

# %%
data[data.RevolvingUtilizationOfUnsecuredLines > 100]
# Out:
#         ID  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 293    294                 0                                  2340   45
# 697    698                 1                                  2066   58
# 1991  1992                 1                                  1143   44
# 2331  2332                 0                                  6324   59
# 4278  4279                 0                                  1982   33
# 4793  4794                 0                                  3746   52
#
#       NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 293                                      0   0.339333           8333
# 697                                      0   0.271121           6000
# 1991                                     2   0.547762           6500
# 2331                                     0   0.136673          11318
# 4278                                     0   0.144982           8000
# ...

# %%
for n in data.columns:
    print '--------------------------'
    print data.groupby(n).size().sort_values(ascending=True).head()
# Out:
# --------------------------
# ID
# 1       1
# 3339    1
# 3338    1
# 3337    1
# 3336    1
# dtype: int64
# --------------------------
# SeriousDlqin2yrs
# 1     305
# 0    4698
# dtype: int64
# --------------------------
# RevolvingUtilizationOfUnsecuredLines
# 0.165360    1
# 0.337521    1
# 0.337527    1
# 0.337664    1
# 0.337736    1
# dtype: int64
# --------------------------
# age
# 99    1
# 96    1
# 95    1
# 97    1
# 94    2
# dtype: int64
# --------------------------
# NumberOfTime30-59DaysPastDueNotWorse
# 10    1
# 12    1
# 7     4
# 98    5
# 6     8
# dtype: int64
# --------------------------
# DebtRatio
# 0.362866    1
# 0.520624    1
# 0.520638    1
# 0.521442    1
# 0.521942    1
# dtype: int64
# --------------------------
# MonthlyIncome
# 5866.0    1
# 7296.0    1
# 7291.0    1
# 7286.0    1
# 7272.0    1
# dtype: int64
# --------------------------
# NumberOfOpenCreditLinesAndLoans
# 46    1
# 32    1
# 31    2
# 33    3
# 29    5
# dtype: int64
# ...

# %%
data.corr()
# Out:
#                                             ID  SeriousDlqin2yrs  \
# ID                                    1.000000          0.017341
# SeriousDlqin2yrs                      0.017341          1.000000
# RevolvingUtilizationOfUnsecuredLines  0.001881          0.016011
# age                                   0.009822         -0.094878
# NumberOfTime30-59DaysPastDueNotWorse  0.022234          0.082438
# DebtRatio                             0.015818         -0.012578
# MonthlyIncome                         0.004182         -0.044652
# NumberOfOpenCreditLinesAndLoans      -0.017552         -0.018392
# NumberOfTimes90DaysLate               0.023213          0.063944
# NumberRealEstateLoansOrLines          0.013155          0.024026
# NumberOfTime60-89DaysPastDueNotWorse  0.021025          0.047164
# NumberOfDependents                    0.000354          0.022325
#
#                                       RevolvingUtilizationOfUnsecuredLines  \
# ...

# %%
sns.

# %%
sns.distplot(data.MonthlyIncome.dropna(axis=0))

# %%
data[data.age > 95]
# Out:
#         ID  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 436    437                 0                              0.007000   97
# 2864  2865                 0                              0.011449   96
# 2922  2923                 0                              0.005043   99
#
#       NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 436                                      0          3            NaN
# 2864                                     0         15            NaN
# 2922                                     0        800            NaN
#
#       NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 436                                 2                        0
# 2864                                3                        0
# 2922                                5                        0
#
#       NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# ...
